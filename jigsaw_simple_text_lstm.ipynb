# %% [markdown]
# # Download data

# %%
from getpass import getpass
import os
user = 'ahmadelsallab'
key = '6b7ffe97ff5bc0656e325b746b72fa31'

if '.kaggle' not in os.listdir('/root'):
    # !mkdir ~/.kaggle
# !touch /root/.kaggle/kaggle.json
# !chmod 666 /root/.kaggle/kaggle.json
with open('/root/.kaggle/kaggle.json', 'w') as f:
    f.write('{"username":"%s","key":"%s"}' % (user, key))
# !chmod 600 /root/.kaggle/kaggle.json


# !kaggle competitions download -c jigsaw-unintended-bias-in-toxicity-classification
# !chmod 777 *
# !ls
# Out:
# sample_submission.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# test.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# train.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# sample_data	       sample_submission.csv.zip  test.csv.zip	train.csv.zip
# sample_submission.csv  test.csv			  train.csv

# %%
# !unzip sample_submission.csv.zip
# !unzip test.csv.zip
# !unzip train.csv.zip
# !ls
# Out:
# Archive:  sample_submission.csv.zip
# replace sample_submission.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# Archive:  test.csv.zip
# replace test.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# Archive:  train.csv.zip
# replace train.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# sample_data	       sample_submission.csv.zip  test.csv.zip	train.csv.zip
# sample_submission.csv  test.csv			  train.csv

# %% [markdown]
# # Explore data samples

# %%
import pandas as pd
train_df = pd.read_csv('train.csv')
train_df.head()
# Out:
#       id    target  ... identity_annotator_count  toxicity_annotator_count
# 0  59848  0.000000  ...                        0                         4
# 1  59849  0.000000  ...                        0                         4
# 2  59852  0.000000  ...                        0                         4
# 3  59855  0.000000  ...                        0                         4
# 4  59856  0.893617  ...                        4                        47
#
# [5 rows x 45 columns]

# %%
import pandas as pd
test_df = pd.read_csv('test.csv')
test_df.head()
# Out:
#         id                                       comment_text
# 0  7000000  Jeff Sessions is another one of Trump's Orwell...
# 1  7000001  I actually inspected the infrastructure on Gra...
# 2  7000002  No it won't . That's just wishful thinking on ...
# 3  7000003  Instead of wringing our hands and nibbling the...
# 4  7000004  how many of you commenters have garbage piled ...

# %% [markdown]
# # Data pre-processing

# %%
import numpy as np

# %%
trn_texts = list(train_df['comment_text'])
tst_texts = list(test_df['comment_text'])
texts = trn_texts + tst_texts

# %%
#from keras.preprocessing.text import Tokenizer, text_to_word_sequence


#tokenizer = Tokenizer()

# %%
#tokenizer.fit_on_texts(np.concatenate([trn_texts, tst_texts]))
words = [word.lower() for text in texts for word in text.split()]
v = sorted(list(set(words)))
str2idx = {w:i for i,w in enumerate(v)}
#idx2str = {i:w for i,w in enumerate(v)}

# %%
del(words)
del(tst_texts)
del(texts)
del(v)

# %%
from keras.preprocessing.sequence import pad_sequences
#from keras.preprocessing.text import Tokenizer, text_to_word_sequence
from keras.preprocessing.text import text_to_word_sequence
#seq_trn_texts = [text_to_word_sequence(t) for t in trn_texts]
# Out:
# Using TensorFlow backend.

# %%
len(seq_trn_texts)
# Out:
# 1804874

# %%
#binary_trn_texts = [[str2idx[w.lower()] for w in text_to_word_sequence(t)] for t in trn_texts] #[str2idx[w.lower()] for t in trn_texts for w in t.split()]
binary_trn_texts = [[str2idx[w.lower()] for w in t.split()] for t in trn_texts]

# %%
len(binary_trn_texts)
# Out:
# 1804874

# %%
del seq_trn_texts

# %%
# TODO: Calc max seqlen
maxlen = max([len(s) for s in binary_trn_texts])
maxlen
#idx = np.argmax([len(s) for s in binary_trn_texts])
#trn_texts[idx]
# Out:
# 317

# %%
x_train = np.array(pad_sequences(binary_trn_texts, maxlen=maxlen))

# %%
x_train.shape

# %%
y_train = train_df['']
