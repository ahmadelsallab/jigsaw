# %% [markdown]
# # Download data

# %%
from getpass import getpass
import os
user = 'ahmadelsallab'
key = '6b7ffe97ff5bc0656e325b746b72fa31'

if '.kaggle' not in os.listdir('/root'):
    # !mkdir ~/.kaggle
# !touch /root/.kaggle/kaggle.json
# !chmod 666 /root/.kaggle/kaggle.json
with open('/root/.kaggle/kaggle.json', 'w') as f:
    f.write('{"username":"%s","key":"%s"}' % (user, key))
# !chmod 600 /root/.kaggle/kaggle.json


# !kaggle competitions download -c jigsaw-unintended-bias-in-toxicity-classification
# !chmod 777 *
# !ls
# Out:
# Downloading sample_submission.csv.zip to /content
#   0% 0.00/221k [00:00<?, ?B/s]
# 100% 221k/221k [00:00<00:00, 60.2MB/s]
# Downloading test.csv.zip to /content
#  41% 5.00M/12.1M [00:00<00:00, 38.4MB/s]
# 100% 12.1M/12.1M [00:00<00:00, 57.7MB/s]
# Downloading train.csv.zip to /content
#  96% 261M/273M [00:02<00:00, 73.2MB/s]
# 100% 273M/273M [00:02<00:00, 105MB/s]
# sample_data  sample_submission.csv.zip	test.csv.zip  train.csv.zip

# %%
# !unzip sample_submission.csv.zip
# !unzip test.csv.zip
# !unzip train.csv.zip
# !ls
# Out:
# Archive:  sample_submission.csv.zip
#   inflating: sample_submission.csv
# Archive:  test.csv.zip
#   inflating: test.csv
# Archive:  train.csv.zip
#   inflating: train.csv
# sample_data	       sample_submission.csv.zip  test.csv.zip	train.csv.zip
# sample_submission.csv  test.csv			  train.csv

# %% [markdown]
# # Explore data samples

# %%
import pandas as pd
train_df = pd.read_csv('train.csv')
train_df.head()
# Out:
#       id    target  ... identity_annotator_count  toxicity_annotator_count
# 0  59848  0.000000  ...                        0                         4
# 1  59849  0.000000  ...                        0                         4
# 2  59852  0.000000  ...                        0                         4
# 3  59855  0.000000  ...                        0                         4
# 4  59856  0.893617  ...                        4                        47
#
# [5 rows x 45 columns]

# %%
import pandas as pd
test_df = pd.read_csv('test.csv')
test_df.head()
# Out:
#         id                                       comment_text
# 0  7000000  Jeff Sessions is another one of Trump's Orwell...
# 1  7000001  I actually inspected the infrastructure on Gra...
# 2  7000002  No it won't . That's just wishful thinking on ...
# 3  7000003  Instead of wringing our hands and nibbling the...
# 4  7000004  how many of you commenters have garbage piled ...

# %% [markdown]
# # Columns correlations

# %% [markdown]
# # Feautres importance with XGBoost
